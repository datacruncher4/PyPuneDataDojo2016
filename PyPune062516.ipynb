# %%
# %matplotlib inline
import os
import pandas as pd
import numpy as np
trains=pd.read_csv("TrainDataSet.csv")

# %%
trains.shape
# Out:
# (69006, 12)

# %%
trains.head()
# Out:
#   Train No.       train Name  islno station Code     Station Name  \
# 0   '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1   '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2   '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3   '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4   '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
#
#   Arrival time Departure time  Distance Source Station Code  \
# 0   '00:00:00'     '22:50:00'         0                BBS
# 1   '01:10:00'     '01:12:00'       166                BBS
# 2   '05:10:00'     '05:30:00'       443                BBS
# 3   '11:10:00'     '11:20:00'       793                BBS
# 4   '16:42:00'     '16:52:00'      1169                BBS
#
#   source Station Name Destination station Code Destination Station Name
# 0     BHUBANESWAR                         BNC           BANGALORE CANT
# 1     BHUBANESWAR                         BNC           BANGALORE CANT
# ...

# %%
stations = trains.groupby(['station Code'])

# %%
for station in stations:
    tr[]

# %%
trains.columns.values
# Out:
# array(['Train No.', 'train Name', 'islno', 'station Code', 'Station Name',
#        'Arrival time', 'Departure time', 'Distance', 'Source Station Code',
#        'source Station Name', 'Destination station Code',
#        'Destination Station Name'], dtype=object)

# %%
tr_nos = trains['Train No.'].unique()

# %%
tr_nos
# Out:
# array(["'00851'", "'00852'", "'01081'", ..., "'83131'", "'83132'",
#        "'84369'"], dtype=object)

# %%
list(tr_nos)
# Out:
# ["'00851'",
#  "'00852'",
#  "'01081'",
#  "'01082'",
#  "'01149'",
#  "'01150'",
#  "'01151'",
#  "'01152'",
#  "'01153'",
#  "'01154'",
#  "'01156'",
#  "'01401'",
#  "'01402'",
#  "'01419'",
#  "'01420'",
#  "'01427'",
#  "'01428'",
#  "'01655'",
#  "'01656'",
#  "'01711'",
#  "'01712'",
#  "'01713'",
#  "'01714'",
#  "'02111'",
#  "'02112'",
#  "'02509'",
#  "'02510'",
#  "'02511'",
#  "'02512'",
#  "'02590'",
#  "'02779'",
#  "'02853'",
#  "'02873'",
#  "'02874'",
#  "'02877'",
#  "'02878'",
#  "'02882'",
#  "'03235'",
#  "'03236'",
#  "'03401'",
#  "'03402'",
#  "'04401'",
#  "'04402'",
#  "'04403'",
#  "'04404'",
#  "'04405'",
#  "'04406'",
#  "'04407'",
#  "'04408'",
#  "'04413'",
#  "'04414'",
#  "'04415'",
#  "'04416'",
#  "'04735'",
#  "'04736'",
#  "'04801'",
#  "'04802'",
#  "'04923'",
#  "'04924'",
#  "'04927'",
#  "'04928'",
#  "'04941'",
#  "'04942'",
#  "'05010'",
#  "'05027'",
#  "'05028'",
#  "'05065'",
#  "'05066'",
#  "'05115'",
#  "'05116'",
#  "'05817'",
# ...

# %%
for nos in tr_nos:

# %%
trains.sort(columns=['islno']).max()
# Out:
# /usr/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
# Train No.                           '84369'
# train Name                  ZIYARAT EXPRESS
# islno                                   120
# station Code                           ZW
# Station Name                ZAWAR
# Arrival time                     '23:59:00'
# Departure time                   '23:59:00'
# Distance                               4273
# Source Station Code                    YPR
# source Station Name         YESVANTPUR JN
# Destination station Code               YPR
# Destination Station Name    YESVANTPUR JN
# dtype: object

# %%
stations = trains["station Code"].unique
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-38b9b5e9cc96> in <module>()
# ----> 1 stations = trains["station Code"].unique
#
# NameError: name 'trains' is not defined

# %%
for station in stations:
    if (trains.["Source Station Code"] == station):
        print trains.[station]
# Out:
#   File "<ipython-input-23-5182bab0536c>", line 2
#     if (trains.["Source Station Code"] == station):
#                ^
# SyntaxError: invalid syntax

# %%
trains["Station Name"]
# Out:
# 0        BHUBANESWAR
# 1        BRAHMAPUR
# 2        VISAKHAPATNAM
# 3        VIJAYAWADA JN
# 4        RENIGUNTA JN
# 5        JOLARPETTAI
# 6        BANGALORE CANT
# 7        BANGALORE CANT
# 8        JOLARPETTAI
# 9        RENIGUNTA JN
# 10       VIJAYAWADA JN
# 11       VISAKHAPATNAM
# 12       BRAHMAPUR
# 13       BHUBANESWAR
# 14       DADAR
# 15       THANE
# 16       KALYAN JN
# 17       IGATPURI
# 18       NASIK ROAD
# 19       CHALISGAON JN
# 20       JALGAON JN
# 21       BHUSAVAL JN
# 22       BHUSAVAL JN
# 23       JALGAON JN
# 24       CHALISGAON JN
# 25       NASIK ROAD
# 26       IGATPURI
# 27       KALYAN JN
# 28       THANE
# 29       DADAR
#               ...
# 68976    CHOPAN
# 68977    AGORI KHAS
# 68978    CHURK
# 68979    ROBERTS GANJ
# 68980    LUSA
# 68981    SAKTESGARH
# 68982    CHUNAR
# 68983    MIRZAPUR
# 68984    VINDHYACHAL
# 68985    MEJA ROAD
# 68986    NAINI
# 68987    ALLAHABAD JN
# 68988    PRAYAG
# 68989    PHAPHAMAU JN
# 68990    RAM CHAURA ROAD
# ...
